# %% [markdown]
# # Imp Jupyter Notebook notes

# %% [markdown]
# ## To add image files to a jupyter notebook locally
#
# ## In code cell:
#
#         from IPython.display import Image
#         Image(filename = 'quora_gyan.png')
#
# ## In markdown cell
#
#         <img src = "quora_gyan.png">

# %%
from IPython.display import Image
Image(filename = 'quora_gyan.png')

# %% [markdown]
# Adding Image in markdown cell
# <img src = "quora_gyan.png">
