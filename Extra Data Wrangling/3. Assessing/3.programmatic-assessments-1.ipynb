# %% [markdown]
# ## Common Programmatic Assessments in pandas
# ### Gather

# %%
import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reactions = pd.read_csv('adverse_reactions.csv')

# %% [markdown]
# ### Assess
# These are the programmatic assessment methods in pandas that you will probably use most often:
#
# * .head (DataFrame and Series)
# * .tail (DataFrame and Series)
# * .sample (DataFrame and Series)
# * .info (DataFrame only)
# * .describe (DataFrame and Series)
# * .value_counts (Series only)
# * Various methods of indexing and selecting data (.loc and bracket notation with/without boolean indexing, also .iloc)
#
# Try them out below and keep their results in mind. Some will come in handy later in the lesson.
#
# Check out the [pandas API reference](https://pandas.pydata.org/pandas-docs/stable/api.html) for detailed usage information.

# %% [markdown]
# Try `.head` and `.tail` on the `patients` table.

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# 1       PamelaSHill@cuvox.de+1 (217) 569-3204   4/3/1967   118.8      66  19.2
# 2            402-363-6804JaeMDebord@gustr.com  2/19/1980   177.8      71  24.8
# 3  PhanBaLiem@jourrapide.com+1 (732) 636-8246  7/26/1951   220.9      70  31.7
# 4             334-515-7487TimNeudorf@cuvox.de  2/18/1928   192.3      27  26.1

# %%
patients.tail()
# Out:
#      patient_id assigned_sex given_name      surname  \
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                       address           city     state  zip_code  \
# 498       2530 Victoria Court   Milton Mills        ME    3852.0
# 499  494 Clarksburg Park Road         Sedona        AZ   86341.0
# 500         649 Nutter Street  Overland Park        MO   64110.0
# 501  3652 Boone Crockett Lane        Seattle        WA   98109.0
# 502         2778 North Avenue           Burr  Nebraska   68324.0
#
#            country                                          contact  \
# 498  United States      207-477-0579MustafaLindstrom@jourrapide.com
# 499  United States               928-284-4492RumanBisliev@gustr.com
# 500  United States            816-223-6007JinkedeKeizer@teleworm.us
# 501  United States  ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# 502  United States             PatrickGersten@rhyta.com402-848-4923
#
#      birthdate  weight  height   bmi
# 498  4/10/1959   181.1      72  24.6
# 499  3/26/1948   239.6      70  34.4
# 500  1/13/1971   171.2      67  26.8
# 501  2/13/1952   176.9      67  27.7
# 502   5/3/1954   138.2      71  19.3

# %% [markdown]
# Try `.sample` on the `treatments` table.

# %%
treatments.sample()
# Out:
#     given_name surname auralin    novodra  hba1c_start  hba1c_end  \
# 272     steven     roy       -  41u - 43u         7.87       7.43
#
#      hba1c_change
# 272          0.94

# %%
treatments.sample(5)
# Out:
#        given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 260         david   beauvais          -  26u - 23u         7.87       7.47
# 56        juliusz   majewski          -  41u - 39u         7.78       7.31
# 125        marcel     peters  48u - 60u          -         9.56       9.19
# 229        sandra     taylor  51u - 58u          -         7.84       7.49
# 134  kwemtochukwu  ogochukwu          -  34u - 37u         7.86       7.53
#
#      hba1c_change
# 260           NaN
# 56           0.97
# 125          0.37
# 229          0.35
# 134           NaN

# %% [markdown]
# Try `.info` on the `treatments` table.

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
# given_name      280 non-null object
# surname         280 non-null object
# auralin         280 non-null object
# novodra         280 non-null object
# hba1c_start     280 non-null float64
# hba1c_end       280 non-null float64
# hba1c_change    171 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %% [markdown]
# Try `.describe` on the `patients` table.

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %% [markdown]
# Try `.value_counts` on the *adverse_reaction* column of the `adverse_reactions` table.

# %%
adverse_reactions['adverse_reaction'].value_counts()
# Out:
# hypoglycemia                 19
# injection site discomfort     6
# headache                      3
# nausea                        2
# throat irritation             2
# cough                         2
# Name: adverse_reaction, dtype: int64

# %% [markdown]
# Try selecting the records in the `patients` table for patients that are from the *city* New York. Check out *Select by conditionals (boolean)* in [Indexing and Selecting Data With Pandas](https://chrisalbon.com/python/pandas_indexing_selecting.html) by Chris Albon if you are stuck.

# %%
len(patients['city'] == 'New York')
# Out:
# 503

# %%
patients.columns
# Out:
# Index(['patient_id', 'assigned_sex', 'given_name', 'surname', 'address',
#        'city', 'state', 'zip_code', 'country', 'contact', 'birthdate',
#        'weight', 'height', 'bmi'],
#       dtype='object')

# %%
patients = patients.set_index('city')

# %%
patients.sample(5)
# Out:
#              patient_id assigned_sex given_name      surname  \
# city
# New Orleans         196       female     Lamara     Dratchev
# Albuquerque          26         male     Gregor         Bole
# Omaha               228       female      Laura  Ehrlichmann
# Gulfport            308       female     Mathea      Lillebø
# Boston              127         male       Mads      Nielsen
#
#                             address state  zip_code        country  \
# city
# New Orleans  3731 Swick Hill Street    LA   70113.0  United States
# Albuquerque       922 Chapmans Lane    NM   87109.0  United States
# Omaha            1829 Bungalow Road    NE   68124.0  United States
# Gulfport        4168 Coventry Court    MS   39501.0  United States
# Boston         1493 Randolph Street    MA    2210.0  United States
#
#                                              contact   birthdate  weight  \
# city
# New Orleans   985-253-7891LamaraDratchev@teleworm.us  10/20/1954   181.3
# Albuquerque         GregorBole@gustr.com505-828-4955   6/19/1922   180.8
# Omaha        402-938-2157LauraEhrlichmann@einrot.com    1/3/1942   187.9
# Gulfport        228-237-2271MatheaLilleb@fleckens.hu  11/30/1928   112.4
# Boston       MadsANielsen@jourrapide.com508-739-5632   5/19/1942   137.1
#
#              height   bmi
# city
# New Orleans      67  28.4
# Albuquerque      67  28.3
# Omaha            60  36.7
# Gulfport         65  18.7
# Boston           68  20.8

# %%
# Select all rows with the index label "New York"
len(patients.loc['New York'])
# Out:
# 18

# %%
patients.loc['New York'].head()
# Out:
#           patient_id assigned_sex given_name   surname               address  \
# city
# New York          10       female     Sophie   Cabrera     3303 Anmoore Road
# New York          36       female     Kamila  Pecinová  3558 Longview Avenue
# New York          85       female      Nương        Vũ   465 Southern Street
# New York         130       female    Rebecca  Jephcott      989 Wayback Lane
# New York         143         male     Finley  Chandler  2754 Westwood Avenue
#
#              state  zip_code        country  \
# city
# New York  New York   10011.0  United States
# New York  New York   10004.0  United States
# New York        NY   10001.0  United States
# New York        NY   10004.0  United States
# New York  New York   10001.0  United States
#
#                                                 contact   birthdate  weight  \
# city
# New York  SophieCabreraIbarra@teleworm.us1 718 795 9124   12/3/1930   194.7
# New York          718-501-0503KamilaPecinova@dayrep.com  12/23/1985   198.9
# New York             VuCamNuong@fleckens.hu516-720-5094    2/1/1981   138.2
# New York        631-370-7406RebeccaJephcott@armyspy.com    8/1/1966   203.3
# New York          516-740-5280FinleyChandler@dayrep.com  10/25/1936   150.9
#
#           height   bmi
# city
# New York      64  33.4
# New York      62  36.4
# New York      63  24.5
# New York      65  33.8
# New York      70  21.6
