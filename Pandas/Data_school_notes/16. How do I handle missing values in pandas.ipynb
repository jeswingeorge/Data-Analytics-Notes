# %%
import pandas as pd
import numpy as np

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %% [markdown]
# NaN - Not a number  -> It means data is missing
#
# ## df.isnull()   - method to detect NA/NaN

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %% [markdown]
# #### Inverse method to detect numbers that are not null -> df.notnull()

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %% [markdown]
# ## To get number of missing values in each column of df

# %%
# Very Imp as it shows were the missing values are
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.isnull().sum(axis=0)   # axis = 0 ->down the columns
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# __isnull() :__ is a series method. It can also be used to filter dataframes

# %%
ufo[ufo['City'].isnull()].head()
# Out:
#     City Colors Reported Shape Reported State             Time
# 21   NaN             NaN            NaN    LA   8/15/1943 0:00
# 22   NaN             NaN          LIGHT    LA   8/15/1943 0:00
# 204  NaN             NaN           DISK    CA  7/15/1952 12:30
# 241  NaN            BLUE           DISK    MT   7/4/1953 14:00
# 613  NaN             NaN           DISK    NV   7/1/1960 12:00

# %%
ufo.loc[ufo['City'].isnull(),:].head()
# Out:
#     City Colors Reported Shape Reported State             Time
# 21   NaN             NaN            NaN    LA   8/15/1943 0:00
# 22   NaN             NaN          LIGHT    LA   8/15/1943 0:00
# 204  NaN             NaN           DISK    CA  7/15/1952 12:30
# 241  NaN            BLUE           DISK    MT   7/4/1953 14:00
# 613  NaN             NaN           DISK    NV   7/1/1960 12:00

# %% [markdown]
# ### How to drop a row from a dataframe if any of its columns values are missing?

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how = 'any').shape
# Out:
# (2486, 5)

# %% [markdown]
# `how = 'any'` comes by default for dropna()

# %%
ufo.dropna().shape
# Out:
# (2486, 5)

# %% [markdown]
# #### How to drop rows of a df based on NA in any 1 or more col

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# To filter out rows based on values in 1 col
ufo.dropna(subset = ['Colors Reported']).head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 12      Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19  Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36  Portsmouth             RED      FORMATION    VA   7/10/1945 1:30
# 44   Blairsden           GREEN         SPHERE    CA  6/30/1946 19:00
# 66     Wexford            BLUE            NaN    PA   7/1/1947 20:00

# %%
# To filter out rows based on values in 2 cols
ufo.dropna(subset = ['City','Colors Reported']).head(10)
# Out:
#              City Colors Reported Shape Reported State             Time
# 12         Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19     Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36     Portsmouth             RED      FORMATION    VA   7/10/1945 1:30
# 44      Blairsden           GREEN         SPHERE    CA  6/30/1946 19:00
# 66        Wexford            BLUE            NaN    PA   7/1/1947 20:00
# 82       San Jose            BLUE        CHEVRON    CA  7/15/1947 21:00
# 84        Modesto            BLUE           DISK    CA   8/8/1947 22:00
# 91         Scipio             RED         SPHERE    IN  5/10/1948 19:00
# 111  Tarrant City          ORANGE         CIRCLE    AL  8/15/1949 22:00
# 120       Roswell             RED            NaN    NM   3/22/1950 0:00

# %%
ufo.dropna(subset = ['City','Colors Reported'], how='any').shape  # If any of the column values are NA
# Out:
# (2877, 5)

# %%
ufo.dropna(subset = ['City','Colors Reported'], how='all').shape   # drop if both have NA
# Out:
# (18221, 5)

# %%
ufo.dropna(how='all').shape  # drop if all values in a column are NA
# Out:
# (18241, 5)

# %% [markdown]
# #### How to replace NA value in a column with any other

# %%
ufo['Colors Reported'].fillna(value = 'WHATEVER').value_counts()
# Out:
# WHATEVER                  15359
# RED                         780
# GREEN                       531
# ORANGE                      528
# BLUE                        450
# YELLOW                      169
# RED GREEN                    89
# RED BLUE                     78
# RED ORANGE                   44
# GREEN BLUE                   34
# RED GREEN BLUE               33
# ORANGE YELLOW                26
# RED YELLOW                   25
# ORANGE GREEN                 23
# YELLOW GREEN                 17
# ORANGE BLUE                  10
# RED YELLOW GREEN              9
# YELLOW BLUE                   6
# ORANGE GREEN BLUE             5
# YELLOW GREEN BLUE             5
# RED YELLOW GREEN BLUE         4
# RED ORANGE YELLOW             4
# RED ORANGE GREEN              3
# RED ORANGE BLUE               3
# RED YELLOW BLUE               3
# ORANGE YELLOW GREEN           1
# RED ORANGE YELLOW BLUE        1
# ORANGE YELLOW BLUE            1
# Name: Colors Reported, dtype: int64

# %% [markdown]
# ### How can I replace the nans with averages of columns where they are?

# %%
df = pd.DataFrame(np.random.randint(5, size = (10,4)))
df.iloc[3:5,0] = np.nan
df.iloc[4:6,1] = np.nan
df.iloc[5:8,2] = np.nan
df.columns = ['A','B','C','D']  # giving names to the columns
df
# Out:
#      A    B    C  D
# 0  2.0  0.0  1.0  3
# 1  2.0  2.0  4.0  0
# 2  0.0  2.0  2.0  1
# 3  NaN  1.0  2.0  0
# 4  NaN  NaN  3.0  3
# 5  0.0  NaN  NaN  1
# 6  1.0  0.0  NaN  0
# 7  0.0  3.0  NaN  1
# 8  1.0  3.0  3.0  3
# 9  0.0  2.0  4.0  2

# %%
df.mean()   # nan values are skipped
# Out:
# A    0.750000
# B    1.625000
# C    2.714286
# D    1.400000
# dtype: float64

# %% [markdown]
# Apply per-column the mean of that columns and fill

# %%
df = df.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
df
# Out:
#       A      B         C  D
# 0  2.00  0.000  1.000000  3
# 1  2.00  2.000  4.000000  0
# 2  0.00  2.000  2.000000  1
# 3  0.75  1.000  2.000000  0
# 4  0.75  1.625  3.000000  3
# 5  0.00  1.625  2.714286  1
# 6  1.00  0.000  2.714286  0
# 7  0.00  3.000  2.714286  1
# 8  1.00  3.000  3.000000  3
# 9  0.00  2.000  4.000000  2

# %% [markdown]
# If you want to impute missing values with mean and you want to go column by column, then this will only impute with the mean of that column. This might be a little more readable.

# %%
df = pd.DataFrame(np.random.randint(5, size = (10,4)))
df.iloc[3:5,0] = np.nan
df.iloc[4:6,1] = np.nan
df.iloc[5:8,2] = np.nan
df.columns = ['A','B','C','D']  # giving names to the columns
df
# Out:
#      A    B    C  D
# 0  0.0  2.0  1.0  0
# 1  2.0  4.0  3.0  4
# 2  2.0  1.0  0.0  3
# 3  NaN  4.0  3.0  3
# 4  NaN  NaN  0.0  1
# 5  3.0  NaN  NaN  1
# 6  4.0  3.0  NaN  1
# 7  0.0  0.0  NaN  1
# 8  0.0  4.0  2.0  0
# 9  2.0  3.0  1.0  1

# %%
df['A'] = df['A'].fillna((df['A'].mean()))
df
# Out:
#        A    B    C  D
# 0  0.000  2.0  1.0  0
# 1  2.000  4.0  3.0  4
# 2  2.000  1.0  0.0  3
# 3  1.625  4.0  3.0  3
# 4  1.625  NaN  0.0  1
# 5  3.000  NaN  NaN  1
# 6  4.000  3.0  NaN  1
# 7  0.000  0.0  NaN  1
# 8  0.000  4.0  2.0  0
# 9  2.000  3.0  1.0  1

# %%
# Similarly
df['B'] = df['B'].fillna((df['B'].mean()))
df['C'] = df['C'].fillna((df['C'].mean()))
df
# Out:
#        A      B         C  D
# 0  0.000  2.000  1.000000  0
# 1  2.000  4.000  3.000000  4
# 2  2.000  1.000  0.000000  3
# 3  1.625  4.000  3.000000  3
# 4  1.625  2.625  0.000000  1
# 5  3.000  2.625  1.428571  1
# 6  4.000  3.000  1.428571  1
# 7  0.000  0.000  1.428571  1
# 8  0.000  4.000  2.000000  0
# 9  2.000  3.000  1.000000  1
