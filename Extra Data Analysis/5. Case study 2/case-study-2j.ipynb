# %%
import pandas as pd

# %%
# load dataset
df = pd.read_csv('combined_dataset.csv')

# %%
df.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 1  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 2  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 3  ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 4  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008   ...     \
# 0            SUV              7.0           15.0          20.0   ...
# 1            SUV              7.0           15.0          20.0   ...
# 2            SUV              7.0           15.0          20.0   ...
# 3            SUV              7.0           15.0          20.0   ...
# 4            SUV              7.0           17.0          22.0   ...
#
#         trans  drive      fuel  veh_class  air_pollution_score  city_mpg  \
# ...

# %%
df.columns
# Out:
# Index(['model_2008', 'displ_2008', 'cyl_2008', 'trans_2008', 'drive_2008',
#        'fuel_2008', 'veh_class_2008', 'air_pollut_2008', 'city_mpg_2008',
#        'hwy_mpg_2008', 'cmb_mpg_2008', 'greenhouse_2008', 'smartway_2008',
#        'model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %% [markdown]
# ### Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?
#
# 1. Create a new dataframe,` model_mpg`, that contain the mean combined mpg values in 2008 and 2018 for each unique model
# To do this, group by model and find the mean cmb_mpg_2008 and mean cmb_mpg for each.
#
# 2. Create a new column, mpg_change, with the change in mpg
# Subtract the mean mpg in 2008 from that in 2018 to get the change in mpg
#
# 3. Find the vehicle that improved the most
# Find the max mpg change, and then use query or indexing to see what model it is!

# %%
## 1
model_mpg = df.groupby(['model_2008', 'model'])['cmb_mpg_2008', 'cmb_mpg'].mean()
model_mpg
# Out:
#                                                          cmb_mpg_2008  \
# model_2008                  model
# ACURA MDX                   ACURA MDX                       17.000000
# ACURA RDX                   ACURA RDX                       19.000000
# AUDI A3                     AUDI A3                         23.333333
# AUDI A4                     AUDI A4                         21.000000
# AUDI A6                     AUDI A6                         19.666667
# AUDI A8 L                   AUDI A8 L                       16.500000
# AUDI Q7                     AUDI Q7                         15.000000
# AUDI R8                     AUDI R8                         15.000000
# AUDI S4                     AUDI S4                         15.500000
# AUDI S5                     AUDI S5                         16.000000
# AUDI S6                     AUDI S6                         16.000000
# AUDI S8                     AUDI S8                         15.000000
# ...

# %%
a = model_mpg.set_index(append = True, list(range(len(model_mpg['mpg_change']))))
a.head(2)
# Out:
#   File "<ipython-input-14-c0efd521341e>", line 1
#     a = model_mpg.set_index(append = True, list(range(len(model_mpg['mpg_change']))))
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
type(model_mpg)
# Out:
# pandas.core.frame.DataFrame

# %%
## 2
model_mpg['mpg_change'] = model_mpg['cmb_mpg_2008'] - model_mpg['cmb_mpg']

# %%
## 3. Find the vehicle that improved the most
# Find the max mpg change, and then use query or indexing to see what model it is!

model_mpg['mpg_change'].argmax()
# Out:
# ('PORSCHE 911 GT3', 'PORSCHE 911 GT3')
